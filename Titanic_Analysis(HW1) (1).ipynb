# %% [markdown]
# # Homework 1: Data Preprocessing and Analyze by pivoting features of Titanic dataset
#
#
#
# *   Uses train.csv and test.csv
# *   Sections will be separated by similar questions.

# %% [markdown]
# # Questions 1 - 6: Basic Data Descriptors
#
# 1.   In **training** set, which features are **available**?
# 2.   In **training** set, which features are **categorical**?
# 3.   In **training** set, which features are **numerical** (e.g., discrete, continuous, or time series based)?
# 4.   In **training** set, which features are mixed data types (Carbin is not mixed data type: [C19 C18
# C17], Ticket is a mixed data type: 342354, SA/12434324)?
# 5.    In **training** set, which features contain blank, null or empty values? In **test** set, which features contain blank, null or empty values?
# 6. In **training** set, what are the data types (e.g., integer, floats or strings) for various features?

# %% [markdown]
# * ***Package Imports and File Input***

# %%
#packages for data pre-processing, analysis, and visualization
#NumPy allows users to perform many different types of dataframe analysis
import numpy as np
#Pandas, built on top of NumPy, allows users to pre-process and clean data, along with analysis tools
import pandas as pd
#seaborn allows users to perform multiple visualization techniques
import seaborn as sns
# %matplotlib inline 
sns.set_theme(style="darkgrid")
#pyplot, part of matplotlib, allows users to plot various types of data
import matplotlib.pyplot as plt

train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')
combine = [train_df, test_df]

# %% [markdown]
# 1.   In **training** set, which features are **available**?

# %%
print(train_df.columns.values)
# Out:
# ['PassengerId' 'Survived' 'Pclass' 'Name' 'Sex' 'Age' 'SibSp' 'Parch'
#  'Ticket' 'Fare' 'Cabin' 'Embarked']

# %% [markdown]
# 2.   In **training** set, which features are **categorical**?
# 3.   In **training** set, which features are **numerical** (e.g., discrete, continuous, or time series based)?
# 4.   In **training** set, which features are mixed data types (Carbin is not mixed data type: [C19 C18
# C17], Ticket is a mixed data type: 342354, SA/12434324)?
# 5.    In **training** set, which features contain blank, null or empty values? In **test** set, which features contain blank, null or empty values?
# 6. In **training** set, what are the data types (e.g., integer, floats or strings) for various features?

# %%
train_df.describe
train_df.tail()
# Out:
#      PassengerId  Survived  Pclass  ...   Fare Cabin  Embarked
# 886          887         0       2  ...  13.00   NaN         S
# 887          888         1       1  ...  30.00   B42         S
# 888          889         0       3  ...  23.45   NaN         S
# 889          890         1       1  ...  30.00  C148         C
# 890          891         0       3  ...   7.75   NaN         Q
#
# [5 rows x 12 columns]

# %%
test_df.describe
test_df.head()
# Out:
#    PassengerId  Pclass  ... Cabin Embarked
# 0          892       3  ...   NaN        Q
# 1          893       3  ...   NaN        S
# 2          894       2  ...   NaN        Q
# 3          895       3  ...   NaN        S
# 4          896       3  ...   NaN        S
#
# [5 rows x 11 columns]

# %% [markdown]
# 1. Training Set:
#
# *   (Question 2) Categorical: Survived, Sex, Embarked, Pclass
# *   (Question 3) Numerical:
#   1. (Discrete): SibSp, Parch
#   2. (Continuous): Age, Fare
# * (Question 4) Mixed Data Types: Ticket
# * (Question 5) Blank, Null, or Empty: Survived, Age, Cabin, Embarked
#
# 2. Test Set:
# * (Question 5) Blank, Null, or Empty: Age, Cabin

# %% [markdown]
# 6. In **training** set, what are the data types (e.g., integer, floats or strings) for various features?

# %%
train_df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ```
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
# ```

# %% [markdown]
# # Questions 7 - 13: Distributions and Correlations
#
# 7. In training set, to understand the distribution of numerical feature values across the samples,
# please list the properties, including count, mean, std, min, 25% percentile, 50% percentile, 75%
# percentile, max, of numerical features?
# 8.  In training set, to understand the distribution of categorical features, we define: count is the total
# number of categorical values per column; unique is the total number of unique categorical values per
# column; top is the most frequent categorical value; freq is the total number of the most frequent
# categorical value. Please list the properties, including count, unique, top, freq, of categorical
# features?
# 9.  In training set, can you observe significant correlation (average survivied ratio>0.5) among the
# group of Pclass=1 and Survived? If Pclass has significant correlation with Survivied, we should
# include this feature in the predictive model. Based on your computation, will you include this feature
# in the predictive model?
# 10. In training set, are Women (Sex=female) were more likely to have survived?
# 11.  In training set, let us start by understanding correlations between a numeric feature (Age) and
# our predictive goal (Survived). A histogram chart is useful for analyzing continuous numerical
# variables like Age where banding or ranges will help identify useful patterns. The histogram can
# indicate distribution of samples using automatically defined bins or equally ranged bands. This helps
# us answer questions relating to specific bands (e.g., infants, old). Please plot the histograms
# between ages and Survived (Figure 1 is an example), and answer the following questions:
# * Do infants (Age <=4) have high survival rate?
# * Do oldest passengers (Age = 80) survive?
# * Do large number of 15-25 year olds not survive?
#
# Based on your analysis of the figures,
# * Should we consider Age in our model training? (If yes, then we should complete the
# Age feature for null values.)
# * Should we should band age groups?
# 12.  In training set, we can combine three features (age, Pclass, and survivied) for identifying
# correlations using a single plot. This can be done with numerical and categorical features which
# have numeric values. Please plot the plot using python, and answer the following questions:
# * Does Pclass=3 have most passengers, however most did not survive?
# * Do infant passengers in Pclass=2 and Pclass=3 mostly survive?
# * Do most passengers in Pclass=1 survive?
# * Does Pclass vary in terms of Age distribution of passengers?
# * Should we consider Pclass for model training?
# 13. In training set, we want to correlate categorical features (with non-numeric values) and numeric
# features. We can consider correlating Embarked (Categorical non-numeric), Sex (Categorical nonnumeric), Fare (Numeric continuous), with Survived (Categorical numeric). Please plot a figure to
# illustrate the correlations of Embarked, Sex, Fare, and Survivied. And answer the following questions:
# * Do higher fare paying passengers have better survival?
# * Should we consider banding fare feature?

# %% [markdown]
# 7.  In training set, to understand the distribution of numerical feature values across the samples,
# please list the properties, including count, mean, std, min, 25% percentile, 50% percentile, 75%
# percentile, max, of numerical features?

# %%
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %% [markdown]
# ![Screenshot_1.png](data:image/png;base64,...)

# %% [markdown]
# 8.  In **training** set, to understand the distribution of categorical features, we define:
# * count is the total number of categorical values per column
# * unique is the total number of unique categorical values per column
# * top is the most frequent categorical value
# * freq is the total number of the most frequent categorical value.
#
# Please list the properties, including count, unique, top, freq, of categorical features.

# %%
# Categorical Features of Training Set: Survived, Sex, Embarked, Pclass

train_df.info()
train_df.describe(include=['O'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#                          Name   Sex Ticket    Cabin Embarked
# count                     891   891    891      204      889
# unique                    891     2    681      147        3
# ...

# %% [markdown]
# 9.  In training set, can you observe significant correlation (average survivied ratio>0.5) among the
# group of Pclass=1 and Survived? If Pclass has significant correlation with Survivied, we should
# include this feature in the predictive model. Based on your computation, will you include this feature
# in the predictive model?

# %%
sns.relplot(x = "Pclass", y = "Survived", kind="line", data = train_df)
plt.show()

# %% [markdown]
# Correlation is significant between Pclass = 1, and those who survived (which is about 65%).
#
# Data should be included.

# %% [markdown]
# 10. In training set, are Women (Sex=female) were more likely to have survived?

# %%
sns.catplot(x = "Sex", y = "Survived", kind="bar", data = train_df)
plt.show()

# %% [markdown]
# Yes, women had about a 55% higher rate of survival.

# %% [markdown]
# 11.  In training set, let us start by understanding correlations between a numeric feature (Age) and
# our predictive goal (Survived). A histogram chart is useful for analyzing continuous numerical
# variables like Age where banding or ranges will help identify useful patterns. The histogram can
# indicate distribution of samples using automatically defined bins or equally ranged bands. This helps
# us answer questions relating to specific bands (e.g., infants, old). Please plot the histograms
# between ages and Survived (Figure 1 is an example), and answer the following questions:
# * Do infants (Age <=4) have high survival rate?
# * Do oldest passengers (Age = 80) survive?
# * Do large number of 15-25 year olds not survive?
#
# ![Screenshot_2.png](data:image/png;base64,...)
#
# Based on your analysis of the figures,
# * Should we consider Age in our model training? (If yes, then we should complete the
# Age feature for null values.)
# * Should we should band age groups?

# %%
g = sns.FacetGrid(train_df, col='Survived')
g.map(plt.hist, 'Age', bins=25)

# %% [markdown]
# Here, we can see age does indeed play a significant role in our data, and should be used in model training.
#
# Banding should occur so that we can group for frequency.

# %% [markdown]
# 12.  In training set, we can combine three features (age, Pclass, and survivied) for identifying
# correlations using a single plot. This can be done with numerical and categorical features which
# have numeric values. Please plot the plot using python, and answer the following questions:
#
# ![Screenshot_3.png](data:image/png;base64,...)
#
# * Does Pclass=3 have most passengers, however most did not survive?
# * Do infant passengers in Pclass=2 and Pclass=3 mostly survive?
# * Do most passengers in Pclass=1 survive?
# * Does Pclass vary in terms of Age distribution of passengers?
# * Should we consider Pclass for model training?

# %%
sns.relplot(x = "Age", y = "Survived", hue="Survived", col="Pclass", style="Survived", data = train_df)
plt.show()

# %% [markdown]
# 13. In training set, we want to correlate categorical features (with non-numeric values) and numeric
# features. We can consider correlating Embarked (Categorical non-numeric), Sex (Categorical nonnumeric), Fare (Numeric continuous), with Survived (Categorical numeric). Please plot a figure to
# illustrate the correlations of Embarked, Sex, Fare, and Survivied. And answer the following questions:
#
# ![Screenshot_4.png](data:image/png;base64,...)
#
# * Do higher fare paying passengers have better survival?
# * Should we consider banding fare feature?

# %%
sns.catplot(x = "Sex", y = "Fare", row="Embarked", col="Survived", kind="bar", data = train_df)
plt.show()

# %% [markdown]
# Higher Fare has correlation with higher survival. It should be banded.

# %% [markdown]
# # Questions 14 - 20: Data Pre-Processing and Analysis
#
# 14.  In training set, what is the rate of duplicates for the Ticket feature? Is there a correlation
# between Ticket and survival? Should we drop the Ticket feature?
# 15. In the training set, Is the Cabin feature complete? How many null values there are in the Cabin
# features of the combined dataset of training and test dataset? Should we drop the Cabin feature?
# 16. In the training set, we can convert features which contain strings to numerical values. This is
# required by most model algorithms. Doing so will also help us in achieving the feature completing
# goal. In this question ,please convert Sex feature to a new feature called Gender where female=1
# and male=0.
# 17. In the training set, we start estimating and completing features with missing or null values. We
# will first do this for the Age feature. We can consider three methods to complete a numerical
# continuous feature. A simple way is to generate random numbers between mean and standard
# deviation. More accurate way of guessing missing values is to use the K-Nearest Neighbor algorithm
# to select the top-K most similar data points, and then use the top-K most similar data points to
# impute the missing values of ages.
# 18.  In the training set, complete a categorical feature: Embarked feature takes S, Q, C values
# based on port of embarkation. Our training dataset has some missing values. Please simply fill these
# with the most common occurrences.
# 19.  In the training set, complete and convert a numeric feature. Please complete the Fare feature
# for single missing value in test dataset using mode to get the value that occurs most frequently for
# this feature.
# 20.  In the training set, convert the Fare feature to ordinal values based on the FareBand (defined in Assignment PDF).

# %%
g = sns.pairplot(train_df[[u'Survived', u'Pclass', u'Sex', u'Age', u'Parch', u'Fare', u'Embarked']], hue='Survived', palette = 'seismic',size=1.2,diag_kind = 'kde',
                 diag_kws=dict(shade=True),plot_kws=dict(s=10) )
g.set(xticklabels=[])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# 14.  In training set, what is the rate of duplicates for the Ticket feature? Is there a correlation
# between Ticket and survival? Should we drop the Ticket feature?

# %%
train_df.describe(include=['O'])
#ticket uniqueness ratio = 891 - 681 = 210/891 * 100% = 23.6%
# Out:
#                          Name   Sex Ticket    Cabin Embarked
# count                     891   891    891      204      889
# unique                    891     2    681      147        3
# top     Radeff, Mr. Alexander  male   1601  B96 B98        S
# freq                        1   577      7        4      644

# %% [markdown]
# * Ticket uniqueness ratio = 891 - 681 = 210/891 * 100% = 23.6%
# * Tickets should be dropped
# * Correlation is not found between ticket and survival

# %% [markdown]
# 15. In the training set, Is the Cabin feature complete? How many null values there are in the Cabin
# features of the combined dataset of training and test dataset? Should we drop the Cabin feature?

# %%
import missingno as msno
msno.bar(test_df)
#train_df.describe(include=['O'])
#cabin completeness ratio = 204/891 * 100% = 22.9%

# %%
msno.bar(train_df)

# %% [markdown]
# * Cabin completeness ratio (training) = 204/891 * 100% = 22.9%
# * Cabin completeness ratio (test) = 91/891 * 100% = 10.2%
# * Cabin completeness ratio (combined) = 151/891 * 100% = 16.9%
# * Cabin should be dropped

# %% [markdown]
# 16. In the training set, we can convert features which contain strings to numerical values. This is
# required by most model algorithms. Doing so will also help us in achieving the feature completing
# goal. In this question ,please convert Sex feature to a new feature called Gender where female=1
# and male=0.

# %%
combine = [train_df, test_df]
#for dataset in combine:
dataset.replace({'sex':{'female':0, 'male':1}}, inplace=True)
g = sns.heatmap(dataset[["Age","Sex","SibSp","Parch","Pclass"]].corr(),cmap="BrBG",annot=True)

# %% [markdown]
# 17. In the training set, we start estimating and completing features with missing or null values. We
# will first do this for the Age feature. We can consider three methods to complete a numerical
# continuous feature. A simple way is to generate random numbers between mean and standard
# deviation. More accurate way of guessing missing values is to use the K-Nearest Neighbor algorithm
# to select the top-K most similar data points, and then use the top-K most similar data points to
# impute the missing values of ages.

# %%
# Out:
#    PassengerId  Survived  Pclass  ... Cabin  Embarked  Title
# 0            1         0       3  ...   NaN         0     Mr
# 1            2         1       1  ...   C85         1    Mrs
# 2            3         1       3  ...   NaN         0   Miss
# 3            4         1       1  ...  C123         0    Mrs
# 4            5         0       3  ...   NaN         0     Mr
#
# [5 rows x 13 columns]

# %% [markdown]
# 18.  In the training set, complete a categorical feature: Embarked feature takes S, Q, C values
# based on port of embarkation. Our training dataset has some missing values. Please simply fill these
# with the most common occurrences.

# %%
highest_embark = train_df.Embarked.dropna().mode()[0]
for dataset in combine:
  dataset['Embarked'] = dataset['Embarked'].fillna(highest_embark)
train_df[['Embarked', 'Survived']].groupby(['Embarked'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Embarked  Survived
# 1         1  0.553571
# 2         2  0.389610
# 0         0  0.339009

# %% [markdown]
# 19.  In the training set, complete and convert a numeric feature. Please complete the Fare feature
# for single missing value in test dataset using mode to get the value that occurs most frequently for
# this feature.

# %%
test_df['Fare'].fillna(test_df['Fare'].dropna().median(), inplace=True)
train_df['BandedF'] = pd.qcut(train_df['Fare'], 4)
train_df[['BandedF', 'Survived']].groupby(['BandedF'], as_index=False).mean().sort_values(by='BandedF', ascending=True)
# Out:
#            BandedF  Survived
# 0   (-0.001, 7.91]  0.197309
# 1   (7.91, 14.454]  0.303571
# 2   (14.454, 31.0]  0.454955
# 3  (31.0, 512.329]  0.581081

# %% [markdown]
# 20.  In the training set, convert the Fare feature to ordinal values based on the FareBand (defined in Assignment PDF).

# %%
#train_df = train_df.drop(['BandedF'], axis=1)
for dataset in combine:
  dataset.loc[ dataset['Fare'] <= 7.91, 'Fare'] = 0
  dataset.loc[(dataset['Fare'] > 7.91) & (dataset['Fare'] <= 14.454), 'Fare'] = 1
  dataset.loc[(dataset['Fare'] > 14.454) & (dataset['Fare'] <= 31), 'Fare'] = 2
  dataset.loc[ dataset['Fare'] > 31, 'Fare'] = 3
  dataset['Fare'] = dataset['Fare'].astype(int)
combine = [train_df, test_df]
train_df.head(50)
# Out:
#     PassengerId  Survived  Pclass  ...        Cabin  Embarked   Title
# 0             1         0       3  ...          NaN         0      Mr
# 1             2         1       1  ...          C85         1     Mrs
# 2             3         1       3  ...          NaN         0    Miss
# 3             4         1       1  ...         C123         0     Mrs
# 4             5         0       3  ...          NaN         0      Mr
# 5             6         0       3  ...          NaN         2      Mr
# 6             7         0       1  ...          E46         0      Mr
# 7             8         0       3  ...          NaN         0  Master
# 8             9         1       3  ...          NaN         0     Mrs
# 9            10         1       2  ...          NaN         1     Mrs
# 10           11         1       3  ...           G6         0    Miss
# 11           12         1       1  ...         C103         0    Miss
# ...
